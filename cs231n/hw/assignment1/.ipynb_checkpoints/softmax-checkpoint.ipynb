# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

from __future__ import print_function

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
loss = 0.0
dW = np.zeros_like(W)

#############################################################################
# TODO: Compute the softmax loss and its gradient using explicit loops.     #
# Store the loss in loss and the gradient in dW. If you are not careful     #
# here, it is easy to run into numeric instability. Don't forget the        #
# regularization!                                                           #
#############################################################################
num_classes = W.shape[1]
num_train = X.shape[0]
for i in np.arange(num_train):
    scores = X[i].dot(W)
    correct_scores = scores[y[i]]
    loss += -1 * correct_scores + np.log(np.sum(np.exp(scores)))
    sum_scores = np.sum(scores)
    for j in np.arange(num_classes):
        if j == y[i]:
            dW[:, y[i]] += -1*X[i] + X[i] * np.exp(correct_scores) / sum_scores
        else:
            dW[:, j] += X[i] * np.exp(scores[j]) / sum_scores
loss = loss / num_train
loss += reg * np.sum(W * W)
dW = dW / num_train
dW += 2*reg*W

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.323177
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.638571 analytic: 0.638571, relative error: 1.414133e-08
# numerical: -0.592293 analytic: -0.592293, relative error: 7.334156e-08
# numerical: 0.709558 analytic: 0.709558, relative error: 2.516819e-08
# numerical: 0.047831 analytic: 0.047831, relative error: 6.183736e-07
# numerical: -0.372769 analytic: -0.372769, relative error: 7.886756e-08
# numerical: -0.384902 analytic: -0.384902, relative error: 2.352933e-07
# numerical: -0.257821 analytic: -0.257821, relative error: 1.360563e-07
# numerical: 0.057522 analytic: 0.057522, relative error: 9.449388e-07
# numerical: 2.849837 analytic: 2.849837, relative error: 3.432463e-08
# numerical: -2.133222 analytic: -2.133222, relative error: 6.483342e-09
# numerical: 2.012606 analytic: 2.012606, relative error: 2.643408e-08
# numerical: -2.639831 analytic: -2.639831, relative error: 2.392059e-08
# numerical: -3.963171 analytic: -3.963171, relative error: 1.711664e-08
# numerical: -0.173080 analytic: -0.173080, relative error: 2.387389e-07
# numerical: -4.550163 analytic: -4.550163, relative error: 1.174696e-08
# numerical: 1.260261 analytic: 1.260261, relative error: 2.190358e-08
# numerical: -3.953318 analytic: -3.953318, relative error: 7.755742e-09
# numerical: -0.086186 analytic: -0.086186, relative error: 5.789080e-08
# numerical: 1.784697 analytic: 1.784697, relative error: 2.342590e-08
# numerical: -0.520509 analytic: -0.520509, relative error: 8.829331e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.323177e+00 computed in 0.116367s
# vectorized loss: 2.323177e+00 computed in 0.003406s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates = [1e-7, 2e-7, 1e-8]
regularization_strengths = [1e4, 2e4, 3e4, 4e4, 5e4, 6e4]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
best_learning_rate = -1
best_reg = -1
for learning_rate in learning_rates:
    for reg in regularization_strengths:
        softmax = Softmax()
        softmax.train(X_train, y_train, learning_rate, reg, num_iters=1000, verbose=True)
        
        y_val_pred = softmax.predict(X_val)
        y_train_pred = softmax.predict(X_train)
        
        train_accuracy = np.mean(y_train == y_train_pred)
        val_accuracy = np.mean(y_val == y_val_pred)
        results[(learning_rate, reg)] = (train_accuracy, val_accuracy)
    
        if val_accuracy > best_val:
            print(val_accuracy)
            print(learning_rate)
            best_val = val_accuracy
            best_learning_rate = learning_rate
            best_reg = reg
            

softmax = Softmax()
loss_hist = softmax.train(X_train, y_train, best_learning_rate, best_reg, num_iters=1500, verbose=True)
y_val_pred = softmax.predict(X_val)
val_accuracy = np.mean(y_val == y_val_pred)
best_val = val_accuracy
best_softmax = softmax
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1000: loss 309.544183
# iteration 100 / 1000: loss 206.475459
# iteration 200 / 1000: loss 138.603954
# iteration 300 / 1000: loss 93.493875
# iteration 400 / 1000: loss 63.080830
# iteration 500 / 1000: loss 42.801781
# iteration 600 / 1000: loss 29.316723
# iteration 700 / 1000: loss 20.263356
# iteration 800 / 1000: loss 14.169668
# iteration 900 / 1000: loss 10.133272
# 0.341
# 1e-07
# iteration 0 / 1000: loss 616.125666
# iteration 100 / 1000: loss 276.242032
# iteration 200 / 1000: loss 124.720270
# iteration 300 / 1000: loss 56.839193
# iteration 400 / 1000: loss 26.579569
# iteration 500 / 1000: loss 13.055151
# iteration 600 / 1000: loss 6.980151
# iteration 700 / 1000: loss 4.288420
# iteration 800 / 1000: loss 3.060798
# iteration 900 / 1000: loss 2.526076
# iteration 0 / 1000: loss 927.547266
# iteration 100 / 1000: loss 278.707212
# iteration 200 / 1000: loss 84.801279
# iteration 300 / 1000: loss 26.821428
# iteration 400 / 1000: loss 9.462489
# iteration 500 / 1000: loss 4.284875
# iteration 600 / 1000: loss 2.684606
# iteration 700 / 1000: loss 2.264651
# iteration 800 / 1000: loss 2.159413
# iteration 900 / 1000: loss 2.137794
# 0.344
# 1e-07
# iteration 0 / 1000: loss 1240.341367
# iteration 100 / 1000: loss 249.667975
# iteration 200 / 1000: loss 51.654636
# iteration 300 / 1000: loss 12.014742
# iteration 400 / 1000: loss 4.154871
# iteration 500 / 1000: loss 2.479728
# iteration 600 / 1000: loss 2.192721
# iteration 700 / 1000: loss 2.143094
# iteration 800 / 1000: loss 2.141625
# iteration 900 / 1000: loss 2.127695
# iteration 0 / 1000: loss 1544.817685
# iteration 100 / 1000: loss 207.777899
# iteration 200 / 1000: loss 29.603769
# iteration 300 / 1000: loss 5.822020
# iteration 400 / 1000: loss 2.643801
# iteration 500 / 1000: loss 2.216035
# iteration 600 / 1000: loss 2.082952
# iteration 700 / 1000: loss 2.176544
# iteration 800 / 1000: loss 2.133479
# iteration 900 / 1000: loss 2.151548
# iteration 0 / 1000: loss 1842.986667
# iteration 100 / 1000: loss 166.101081
# iteration 200 / 1000: loss 16.767830
# iteration 300 / 1000: loss 3.473609
# iteration 400 / 1000: loss 2.272157
# iteration 500 / 1000: loss 2.101393
# iteration 600 / 1000: loss 2.156642
# iteration 700 / 1000: loss 2.206717
# iteration 800 / 1000: loss 2.172963
# iteration 900 / 1000: loss 2.141728
# iteration 0 / 1000: loss 308.952370
# iteration 100 / 1000: loss 137.445266
# iteration 200 / 1000: loss 62.539758
# iteration 300 / 1000: loss 28.929098
# iteration 400 / 1000: loss 14.094616
# iteration 500 / 1000: loss 7.420882
# iteration 600 / 1000: loss 4.455233
# iteration 700 / 1000: loss 3.092070
# iteration 800 / 1000: loss 2.444225
# iteration 900 / 1000: loss 2.179443
# 0.37
# 2e-07
# iteration 0 / 1000: loss 613.203553
# iteration 100 / 1000: loss 123.402218
# iteration 200 / 1000: loss 26.322108
# iteration 300 / 1000: loss 6.881763
# iteration 400 / 1000: loss 2.987025
# iteration 500 / 1000: loss 2.225829
# iteration 600 / 1000: loss 2.128464
# iteration 700 / 1000: loss 2.102061
# iteration 800 / 1000: loss 2.098039
# iteration 900 / 1000: loss 2.040478
# iteration 0 / 1000: loss 934.750794
# iteration 100 / 1000: loss 84.972236
# iteration 200 / 1000: loss 9.365937
# iteration 300 / 1000: loss 2.757618
# iteration 400 / 1000: loss 2.248236
# iteration 500 / 1000: loss 2.074146
# iteration 600 / 1000: loss 2.075529
# iteration 700 / 1000: loss 2.072457
# iteration 800 / 1000: loss 2.136864
# iteration 900 / 1000: loss 2.080622
# iteration 0 / 1000: loss 1233.728398
# iteration 100 / 1000: loss 50.766493
# iteration 200 / 1000: loss 4.039931
# iteration 300 / 1000: loss 2.201048
# iteration 400 / 1000: loss 2.159267
# iteration 500 / 1000: loss 2.065805
# iteration 600 / 1000: loss 2.135042
# iteration 700 / 1000: loss 2.109492
# iteration 800 / 1000: loss 2.119081
# iteration 900 / 1000: loss 2.148425
# iteration 0 / 1000: loss 1517.236509
# iteration 100 / 1000: loss 28.596228
# iteration 200 / 1000: loss 2.614860
# iteration 300 / 1000: loss 2.129300
# iteration 400 / 1000: loss 2.113382
# iteration 500 / 1000: loss 2.171222
# iteration 600 / 1000: loss 2.173443
# iteration 700 / 1000: loss 2.128845
# iteration 800 / 1000: loss 2.111544
# iteration 900 / 1000: loss 2.139893
# iteration 0 / 1000: loss 1835.957327
# iteration 100 / 1000: loss 16.300406
# iteration 200 / 1000: loss 2.220573
# iteration 300 / 1000: loss 2.185930
# iteration 400 / 1000: loss 2.144160
# iteration 500 / 1000: loss 2.208833
# iteration 600 / 1000: loss 2.155483
# iteration 700 / 1000: loss 2.127147
# iteration 800 / 1000: loss 2.172689
# iteration 900 / 1000: loss 2.178854
# iteration 0 / 1000: loss 313.710987
# iteration 100 / 1000: loss 301.229374
# iteration 200 / 1000: loss 288.615650
# iteration 300 / 1000: loss 277.407163
# iteration 400 / 1000: loss 266.232626
# iteration 500 / 1000: loss 255.957879
# iteration 600 / 1000: loss 245.836168
# iteration 700 / 1000: loss 235.785730
# iteration 800 / 1000: loss 226.744814
# iteration 900 / 1000: loss 217.771872
# iteration 0 / 1000: loss 613.685129
# iteration 100 / 1000: loss 566.393236
# iteration 200 / 1000: loss 523.135932
# iteration 300 / 1000: loss 482.388090
# iteration 400 / 1000: loss 445.504430
# iteration 500 / 1000: loss 411.058220
# iteration 600 / 1000: loss 379.548638
# iteration 700 / 1000: loss 350.358845
# iteration 800 / 1000: loss 323.207013
# iteration 900 / 1000: loss 298.422974
# iteration 0 / 1000: loss 928.884216
# iteration 100 / 1000: loss 823.418873
# iteration 200 / 1000: loss 730.479071
# iteration 300 / 1000: loss 647.776777
# iteration 400 / 1000: loss 574.746225
# iteration 500 / 1000: loss 509.721158
# iteration 600 / 1000: loss 452.098226
# iteration 700 / 1000: loss 400.811406
# iteration 800 / 1000: loss 355.855178
# iteration 900 / 1000: loss 315.669019
# iteration 0 / 1000: loss 1233.928342
# iteration 100 / 1000: loss 1051.437436
# iteration 200 / 1000: loss 895.764597
# iteration 300 / 1000: loss 763.077772
# iteration 400 / 1000: loss 650.144761
# iteration 500 / 1000: loss 554.128667
# iteration 600 / 1000: loss 472.103818
# iteration 700 / 1000: loss 402.550810
# iteration 800 / 1000: loss 343.203336
# iteration 900 / 1000: loss 292.611214
# iteration 0 / 1000: loss 1546.948508
# iteration 100 / 1000: loss 1266.118991
# iteration 200 / 1000: loss 1036.626982
# iteration 300 / 1000: loss 848.639944
# iteration 400 / 1000: loss 695.034829
# iteration 500 / 1000: loss 569.179860
# iteration 600 / 1000: loss 466.080029
# iteration 700 / 1000: loss 381.747928
# iteration 800 / 1000: loss 312.962704
# iteration 900 / 1000: loss 256.292281
# iteration 0 / 1000: loss 1811.287053
# iteration 100 / 1000: loss 1424.795076
# iteration 200 / 1000: loss 1121.170706
# iteration 300 / 1000: loss 881.415522
# iteration 400 / 1000: loss 693.512843
# iteration 500 / 1000: loss 545.720189
# iteration 600 / 1000: loss 429.546722
# iteration 700 / 1000: loss 338.120465
# iteration 800 / 1000: loss 266.204746
# iteration 900 / 1000: loss 209.894873
# iteration 0 / 1500: loss 317.469231
# iteration 100 / 1500: loss 141.677858
# iteration 200 / 1500: loss 64.374604
# iteration 300 / 1500: loss 29.806814
# iteration 400 / 1500: loss 14.420935
# iteration 500 / 1500: loss 7.491575
# iteration 600 / 1500: loss 4.465941
# iteration 700 / 1500: loss 3.132207
# iteration 800 / 1500: loss 2.500707
# iteration 900 / 1500: loss 2.198753
# iteration 1000 / 1500: loss 2.051716
# iteration 1100 / 1500: loss 2.025513
# iteration 1200 / 1500: loss 2.013945
# iteration 1300 / 1500: loss 2.072567
# iteration 1400 / 1500: loss 1.998209
# lr 1.000000e-08 reg 1.000000e+04 train accuracy: 0.141694 val accuracy: 0.143000
# lr 1.000000e-08 reg 2.000000e+04 train accuracy: 0.137959 val accuracy: 0.137000
# lr 1.000000e-08 reg 3.000000e+04 train accuracy: 0.157122 val accuracy: 0.175000
# lr 1.000000e-08 reg 4.000000e+04 train accuracy: 0.157469 val accuracy: 0.155000
# lr 1.000000e-08 reg 5.000000e+04 train accuracy: 0.160265 val accuracy: 0.151000
# lr 1.000000e-08 reg 6.000000e+04 train accuracy: 0.178143 val accuracy: 0.163000
# lr 1.000000e-07 reg 1.000000e+04 train accuracy: 0.333347 val accuracy: 0.341000
# lr 1.000000e-07 reg 2.000000e+04 train accuracy: 0.339020 val accuracy: 0.341000
# lr 1.000000e-07 reg 3.000000e+04 train accuracy: 0.320061 val accuracy: 0.344000
# lr 1.000000e-07 reg 4.000000e+04 train accuracy: 0.314163 val accuracy: 0.331000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.296633 val accuracy: 0.321000
# lr 1.000000e-07 reg 6.000000e+04 train accuracy: 0.302673 val accuracy: 0.312000
# lr 2.000000e-07 reg 1.000000e+04 train accuracy: 0.359041 val accuracy: 0.370000
# lr 2.000000e-07 reg 2.000000e+04 train accuracy: 0.335163 val accuracy: 0.352000
# lr 2.000000e-07 reg 3.000000e+04 train accuracy: 0.319041 val accuracy: 0.333000
# lr 2.000000e-07 reg 4.000000e+04 train accuracy: 0.314592 val accuracy: 0.331000
# lr 2.000000e-07 reg 5.000000e+04 train accuracy: 0.293755 val accuracy: 0.309000
# lr 2.000000e-07 reg 6.000000e+04 train accuracy: 0.307449 val accuracy: 0.315000
# best validation accuracy achieved during cross-validation: 0.375000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.367000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
